# %%
import tensorflow as tf

# Check GPU availability
if tf.test.gpu_device_name():
    print('GPU device found')
else:
    print("No GPU found")
# Out:
# GPU device found

# %%
# TensorFlow and tf.keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow import keras
from sklearn.model_selection import train_test_split
from __future__ import absolute_import , division , print_function , unicode_literals
from sklearn.preprocessing import StandardScaler

# %%
def loop_categories(df):
    for i in df.columns:
        if df[i].dtype != int or df[i].dtype != float:
            categories = df[i].unique()
            for j in categories:
                df[i] = df[i].replace(j, categories.tolist().index(j))
    return df

# %%
df=pd.read_csv('train.csv')
df = loop_categories(df)
X,y=df.iloc[:, :-1],df.HeartDisease
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33, random_state=42)
scaler = StandardScaler()
X_train,X_test  = scaler.fit_transform(X_train),scaler.transform(X_test)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(8, activation='relu'),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=20, validation_split=0.2)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 21/21 [==============================] - 1s 13ms/step - loss: 0.7286 - accuracy: 0.4877 - val_loss: 0.7093 - val_accuracy: 0.3725
# Epoch 2/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6955 - accuracy: 0.5784 - val_loss: 0.6905 - val_accuracy: 0.4314
# Epoch 3/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6859 - accuracy: 0.5760 - val_loss: 0.6754 - val_accuracy: 0.5392
# Epoch 4/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6841 - accuracy: 0.6201 - val_loss: 0.6621 - val_accuracy: 0.6765
# Epoch 5/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6612 - accuracy: 0.6471 - val_loss: 0.6476 - val_accuracy: 0.7451
# Epoch 6/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6463 - accuracy: 0.7034 - val_loss: 0.6309 - val_accuracy: 0.7941
# Epoch 7/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6476 - accuracy: 0.6593 - val_loss: 0.6122 - val_accuracy: 0.8431
# Epoch 8/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6250 - accuracy: 0.6985 - val_loss: 0.5940 - val_accuracy: 0.8824
# Epoch 9/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.6112 - accuracy: 0.7108 - val_loss: 0.5750 - val_accuracy: 0.8824
# Epoch 10/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5875 - accuracy: 0.7402 - val_loss: 0.5530 - val_accuracy: 0.8725
# Epoch 11/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5644 - accuracy: 0.7721 - val_loss: 0.5294 - val_accuracy: 0.8627
# Epoch 12/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5634 - accuracy: 0.7966 - val_loss: 0.5090 - val_accuracy: 0.8725
# Epoch 13/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5458 - accuracy: 0.7500 - val_loss: 0.4900 - val_accuracy: 0.8824
# Epoch 14/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5207 - accuracy: 0.7819 - val_loss: 0.4680 - val_accuracy: 0.8725
# Epoch 15/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5128 - accuracy: 0.7672 - val_loss: 0.4483 - val_accuracy: 0.8725
# Epoch 16/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5009 - accuracy: 0.7868 - val_loss: 0.4317 - val_accuracy: 0.8725
# Epoch 17/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4986 - accuracy: 0.7843 - val_loss: 0.4176 - val_accuracy: 0.8725
# Epoch 18/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4979 - accuracy: 0.7794 - val_loss: 0.4074 - val_accuracy: 0.8922
# Epoch 19/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4916 - accuracy: 0.7990 - val_loss: 0.3981 - val_accuracy: 0.8922
# Epoch 20/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4821 - accuracy: 0.8113 - val_loss: 0.3931 - val_accuracy: 0.9020
# Epoch 21/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4556 - accuracy: 0.8284 - val_loss: 0.3818 - val_accuracy: 0.8922
# Epoch 22/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.4167 - accuracy: 0.8505 - val_loss: 0.3709 - val_accuracy: 0.8922
# Epoch 23/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.4400 - accuracy: 0.8137 - val_loss: 0.3622 - val_accuracy: 0.9020
# Epoch 24/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4373 - accuracy: 0.8137 - val_loss: 0.3596 - val_accuracy: 0.9020
# Epoch 25/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.4507 - accuracy: 0.8211 - val_loss: 0.3536 - val_accuracy: 0.9118
# Epoch 26/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4529 - accuracy: 0.8113 - val_loss: 0.3480 - val_accuracy: 0.9216
# Epoch 27/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4261 - accuracy: 0.8505 - val_loss: 0.3442 - val_accuracy: 0.9216
# Epoch 28/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4302 - accuracy: 0.8260 - val_loss: 0.3406 - val_accuracy: 0.9216
# Epoch 29/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4261 - accuracy: 0.8407 - val_loss: 0.3345 - val_accuracy: 0.9216
# Epoch 30/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4154 - accuracy: 0.8431 - val_loss: 0.3323 - val_accuracy: 0.9216
# Epoch 31/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4199 - accuracy: 0.8382 - val_loss: 0.3267 - val_accuracy: 0.9118
# Epoch 32/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4262 - accuracy: 0.8211 - val_loss: 0.3236 - val_accuracy: 0.9118
# Epoch 33/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4234 - accuracy: 0.8431 - val_loss: 0.3224 - val_accuracy: 0.9118
# Epoch 34/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4274 - accuracy: 0.8456 - val_loss: 0.3222 - val_accuracy: 0.9118
# Epoch 35/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4085 - accuracy: 0.8456 - val_loss: 0.3197 - val_accuracy: 0.9118
# Epoch 36/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4232 - accuracy: 0.8407 - val_loss: 0.3185 - val_accuracy: 0.9118
# Epoch 37/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4282 - accuracy: 0.8407 - val_loss: 0.3163 - val_accuracy: 0.9118
# Epoch 38/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.8235 - val_loss: 0.3132 - val_accuracy: 0.9118
# Epoch 39/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3940 - accuracy: 0.8407 - val_loss: 0.3125 - val_accuracy: 0.9118
# Epoch 40/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4019 - accuracy: 0.8529 - val_loss: 0.3103 - val_accuracy: 0.9118
# Epoch 41/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4054 - accuracy: 0.8529 - val_loss: 0.3082 - val_accuracy: 0.9118
# Epoch 42/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4152 - accuracy: 0.8333 - val_loss: 0.3043 - val_accuracy: 0.9118
# Epoch 43/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.3966 - accuracy: 0.8358 - val_loss: 0.3021 - val_accuracy: 0.9118
# Epoch 44/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.3849 - accuracy: 0.8480 - val_loss: 0.3007 - val_accuracy: 0.9118
# Epoch 45/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.3988 - accuracy: 0.8382 - val_loss: 0.2988 - val_accuracy: 0.9118
# Epoch 46/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4159 - accuracy: 0.8358 - val_loss: 0.2984 - val_accuracy: 0.9118
# Epoch 47/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4074 - accuracy: 0.8382 - val_loss: 0.2984 - val_accuracy: 0.9118
# Epoch 48/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4089 - accuracy: 0.8456 - val_loss: 0.2992 - val_accuracy: 0.9118
# Epoch 49/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4090 - accuracy: 0.8407 - val_loss: 0.2963 - val_accuracy: 0.9118
# Epoch 50/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.8431 - val_loss: 0.2949 - val_accuracy: 0.9118
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8413
# Test accuracy: 0.841269850730896
